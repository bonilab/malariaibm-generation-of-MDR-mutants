# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 12]
rc = {"font.family" : "sans-serif", 
      "font.style" : "normal",
      "mathtext.fontset" : "dejavusans"}
plt.rcParams.update(rc)
plt.rcParams["font.sans-serif"] = ["Myriad Pro"] + plt.rcParams["font.sans-serif"]

# %%
from plotter import plot_fig_b_for_one_set

# %% [markdown]
# Set 7's

# %%
# set 7 (5% PfPR, 40% coverage), no_184
plot_fig_b_for_one_set('simulation_outputs/dxg_no_184/set7', 'saved_figures/set7_dxg_no_184.svg', figtitle='on')

# %%
# set 7 (5% PfPR, 40% coverage), no_mdr1
plot_fig_b_for_one_set('simulation_outputs/dxg_no_mdr1/set7', 'saved_figures/set7_dxg_no_mdr1.svg', figtitle='on')

# %%
# set 7 (5% PfPR, 40% coverage), no_184_nor_mdr1
plot_fig_b_for_one_set('simulation_outputs/dxg_no_184_nor_mdr1/set7', 'saved_figures/set7_dxg_no_184_nor_mdr1.svg', figtitle='on')

# %% [markdown]
# Set 5's

# %%
# set 5 (0.1% PfPR, 40% coverage), no_184
plot_fig_b_for_one_set('simulation_outputs/dxg_no_184/set5', 'saved_figures/set5_dxg_no_184.svg', figtitle='on')

# %%
# set 5 (0.1% PfPR, 40% coverage), no_mdr1
plot_fig_b_for_one_set('simulation_outputs/dxg_no_mdr1/set5', 'saved_figures/set5_dxg_no_mdr1.svg', figtitle='on')

# %%
# set 5 (0.1% PfPR, 40% coverage), no_184_nor_mdr1
plot_fig_b_for_one_set('simulation_outputs/dxg_no_184_nor_mdr1/set5', 'saved_figures/set5_dxg_no_184_nor_mdr1.svg', figtitle='on')
