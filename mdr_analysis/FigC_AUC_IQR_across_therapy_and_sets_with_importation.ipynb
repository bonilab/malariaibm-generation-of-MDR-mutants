# %% [markdown]
# # Fig.3 - Comparisons of MDR's AUC across 12 different sets

# %%
plot_savepath = 'saved_figures/FigC_AUC_IQR_imp'

# %% [markdown]
# Change plot's default size and font

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 12]
rc = {"font.family" : "sans-serif", 
      "font.style" : "normal",
      "mathtext.fontset" : "dejavusans"}
plt.rcParams.update(rc)
plt.rcParams["font.sans-serif"] = ["Myriad Pro"] + plt.rcParams["font.sans-serif"]

# %%
TITLE_FONTSIZE = 20
XLABEL_FONTSIZE = 20
YLABEL_PADDING = 190

# %%
from plotter import fig_c_auc_calculation
from scipy.stats import mannwhitneyu
fig, axes = plt.subplots(5, 3, sharex='col', sharey='row',
                        gridspec_kw={'hspace': 0, 'wspace': 0})
fig.patch.set_facecolor('white')
labels = ['MFT', '5-Year Cycling', 'Adaptive Cycling']

for rownum in range(5):
  if rownum == 0:
    for idx, covtext in enumerate([20,40,60]):
      axes[0][idx].set_title(f'{covtext}% coverage', fontsize=XLABEL_FONTSIZE)
  # last row is 50% PfPR
  # which was introduced in revision
  # hence does not follow previous naming order
  if rownum == 4:
    set_list = [13,14,15]
  else:
    set_list = [1+rownum,5+rownum,9+rownum]
  for (a,idx) in zip(set_list,[0,1,2]): # setnum, indexnum
    print(f'=== Set {a} ===')
    fdir_path = f'simulation_outputs/with_importation_every_5_year/set{a}'
    print('{:10s} = '.format('MFT'), end='')
    aucs_m, box_m = fig_c_auc_calculation(
      fdir_path+'_m/', 
      'MFT', 
      verbose='on'
    )
    print('{:10s} = '.format('5-yr Cyc'), end='')
    aucs_c, box_c = fig_c_auc_calculation(
      fdir_path+'_c/', 
      '5-Year Cycling',
      verbose='on'
    )
    print('{:10s} = '.format('Adp Cyc'), end='')
    aucs_ac, box_ac = fig_c_auc_calculation(
      fdir_path+'_ac/', 
      'Adaptive Cycling',
      verbose='on'
    )
    bplot = axes[rownum][idx].bxp(
      [box_m, box_c, box_ac], 
      showfliers=False, 
      vert=False, 
      patch_artist=True,
      medianprops=dict(color='k')
    )
    colors = ['#cadab0', '#a6cfd8', '#d1a29b'] # green, blue, coral
    for patch, color in zip(bplot['boxes'], colors):
      patch.set_facecolor(color)
    _, p_m_vs_c = mannwhitneyu(aucs_m, aucs_c)
    _, p_m_vs_a = mannwhitneyu(aucs_m, aucs_ac)
    print(f'** MFT vs 5-yr-Cyc Mann-Whitney p-value: {p_m_vs_c} **')
    print(f'** MFT vs Adpt-Cyc Mann-Whitney p-value: {p_m_vs_a} **')
    
  
for c in range(5):
  for tick in axes[c][0].yaxis.get_major_ticks():
    tick.label.set_fontsize(XLABEL_FONTSIZE)

axes[0][0].set_ylabel('PfPR = 0.1%', multialignment='left', 
                     horizontalalignment='left', rotation=0, 
                     fontsize=XLABEL_FONTSIZE, labelpad=YLABEL_PADDING)
axes[1][0].set_ylabel('PfPR = 1%', multialignment='left', 
                     horizontalalignment='left', rotation=0, 
                     fontsize=XLABEL_FONTSIZE, labelpad=YLABEL_PADDING)
axes[2][0].set_ylabel('PfPR = 5%', multialignment='left', 
                     horizontalalignment='left', rotation=0, 
                     fontsize=XLABEL_FONTSIZE, labelpad=YLABEL_PADDING)
axes[3][0].set_ylabel('PfPR = 25%', multialignment='left', 
                     horizontalalignment='left', rotation=0, 
                     fontsize=XLABEL_FONTSIZE, labelpad=YLABEL_PADDING)
axes[4][0].set_ylabel('PfPR = 50%', multialignment='left', 
                     horizontalalignment='left', rotation=0, 
                     fontsize=XLABEL_FONTSIZE, labelpad=YLABEL_PADDING)

for c in range(3):
  for tick in axes[3][c].xaxis.get_major_ticks():
    tick.label.set_fontsize(XLABEL_FONTSIZE-4)

fig.add_subplot(111, frameon=False)
# hide tick and tick label of the big axis
plt.tick_params(labelcolor='none', top=False, bottom=False, left=False, right=False)
# add common x- and y-labels
plt.xlabel('AUC', fontsize=XLABEL_FONTSIZE)

if plot_savepath != '':
  plt.savefig(fname=plot_savepath+'.svg', format='svg', bbox_inches='tight')
# Out:
# === Set 1 ===
# MFT        =    9.60 (   3.08-  24.45)
# 5-yr Cyc   =    8.65 (   2.99-  22.97)
# Adp Cyc    =   13.39 (   3.24-  37.71)
# ** MFT vs 5-yr-Cyc Mann-Whitney p-value: 0.490032357071569 **
# ** MFT vs Adpt-Cyc Mann-Whitney p-value: 0.3205941872370386 **
# === Set 5 ===
# MFT        =   34.80 (   7.69- 425.02)
# 5-yr Cyc   =   60.17 (   9.72- 240.53)
# Adp Cyc    =  156.50 (  13.83-1179.11)
# ** MFT vs 5-yr-Cyc Mann-Whitney p-value: 0.8173922966401168 **
# ** MFT vs Adpt-Cyc Mann-Whitney p-value: 0.017492183067947822 **
# === Set 9 ===
# MFT        = 1370.90 ( 962.19-2014.13)
# 5-yr Cyc   = 1571.04 (1063.09-2188.23)
# Adp Cyc    = 1301.70 ( 906.91-1892.95)
# ** MFT vs 5-yr-Cyc Mann-Whitney p-value: 0.33021006844803324 **
# ** MFT vs Adpt-Cyc Mann-Whitney p-value: 0.38238432600147465 **
# === Set 2 ===
# MFT        =    8.05 (   3.02-  19.42)
# 5-yr Cyc   =    9.20 (   3.14-  16.90)
# Adp Cyc    =   14.01 (   3.42-  38.26)
# ** MFT vs 5-yr-Cyc Mann-Whitney p-value: 0.8940631319544825 **
# ** MFT vs Adpt-Cyc Mann-Whitney p-value: 0.06108805399734322 **
# === Set 6 ===
# MFT        =   82.94 (  30.96- 190.95)
# 5-yr Cyc   =   91.31 (  34.63- 341.06)
# Adp Cyc    =  405.58 ( 151.91-1157.81)
# ** MFT vs 5-yr-Cyc Mann-Whitney p-value: 0.21587314314741302 **
# ** MFT vs Adpt-Cyc Mann-Whitney p-value: 1.784059404678544e-12 **
# === Set 10 ===
# MFT        =  714.39 ( 273.51-1618.88)
# 5-yr Cyc   =  823.10 ( 237.13-2247.59)
# Adp Cyc    = 1647.59 ( 421.33-3454.74)
# ** MFT vs 5-yr-Cyc Mann-Whitney p-value: 0.4292730068341283 **
# ** MFT vs Adpt-Cyc Mann-Whitney p-value: 0.001535687831992728 **
# === Set 3 ===
# MFT        =    8.97 (   5.32-  14.41)
# 5-yr Cyc   =    9.77 (   6.69-  18.90)
# Adp Cyc    =   30.19 (  15.71-  56.65)
# ** MFT vs 5-yr-Cyc Mann-Whitney p-value: 0.16040018429215808 **
# ** MFT vs Adpt-Cyc Mann-Whitney p-value: 1.0316200646431882e-18 **
# === Set 7 ===
# MFT        =  126.35 (  84.80- 180.03)
# 5-yr Cyc   =  269.60 ( 176.14- 391.88)
# Adp Cyc    =  621.88 ( 421.71- 813.95)
# ** MFT vs 5-yr-Cyc Mann-Whitney p-value: 5.428957894979082e-13 **
# ** MFT vs Adpt-Cyc Mann-Whitney p-value: 1.647914847990066e-31 **
# === Set 11 ===
# MFT        = 2031.08 (1595.93-2349.07)
# 5-yr Cyc   = 2497.18 (2159.64-2986.95)
# Adp Cyc    = 2812.20 (2377.79-3147.92)
# ** MFT vs 5-yr-Cyc Mann-Whitney p-value: 4.905760945401716e-10 **
# ** MFT vs Adpt-Cyc Mann-Whitney p-value: 2.453770739096413e-17 **
# === Set 4 ===
# MFT        =    9.36 (   6.67-  12.92)
# 5-yr Cyc   =   11.38 (   7.90-  14.88)
# Adp Cyc    =   29.42 (  21.79-  38.57)
# ** MFT vs 5-yr-Cyc Mann-Whitney p-value: 0.01943390857842529 **
# ** MFT vs Adpt-Cyc Mann-Whitney p-value: 1.8429498975249981e-29 **
# === Set 8 ===
# MFT        =  121.86 ( 105.04- 146.90)
# 5-yr Cyc   =  255.86 ( 209.95- 327.38)
# Adp Cyc    =  369.29 ( 283.89- 451.14)
# ** MFT vs 5-yr-Cyc Mann-Whitney p-value: 1.3576427099611074e-29 **
# ** MFT vs Adpt-Cyc Mann-Whitney p-value: 1.1423059689186594e-33 **
# === Set 12 ===
# MFT        = 1452.92 (1308.05-1583.86)
# 5-yr Cyc   = 1940.23 (1821.81-2084.27)
# Adp Cyc    = 1531.42 (1423.56-1692.65)
# ** MFT vs 5-yr-Cyc Mann-Whitney p-value: 7.530093548321171e-29 **
# ** MFT vs Adpt-Cyc Mann-Whitney p-value: 0.0006444256852964615 **
# === Set 13 ===
# MFT        =    8.69 (   6.49-  11.31)
# 5-yr Cyc   =   13.99 (  11.05-  18.15)
# Adp Cyc    =   28.78 (  23.52-  34.56)
# ** MFT vs 5-yr-Cyc Mann-Whitney p-value: 2.8843305478425104e-15 **
# ** MFT vs Adpt-Cyc Mann-Whitney p-value: 3.964245072235026e-33 **
# === Set 14 ===
# MFT        =  125.78 ( 105.52- 146.37)
# 5-yr Cyc   =  241.63 ( 215.28- 286.74)
# Adp Cyc    =  259.84 ( 219.22- 305.74)
# ** MFT vs 5-yr-Cyc Mann-Whitney p-value: 1.2841615669058746e-29 **
# ** MFT vs Adpt-Cyc Mann-Whitney p-value: 1.5302560323079166e-32 **
# === Set 15 ===
# MFT        = 1025.79 ( 942.32-1110.76)
# 5-yr Cyc   = 1365.77 (1253.34-1500.75)
# Adp Cyc    = 1229.12 (1124.71-1333.09)
# ** MFT vs 5-yr-Cyc Mann-Whitney p-value: 2.127912628227152e-28 **
# ** MFT vs Adpt-Cyc Mann-Whitney p-value: 4.404633090660304e-17 **
